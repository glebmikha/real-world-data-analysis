# %%
import pandas as pd

# %%
df = pd.read_csv('../data/data.csv',encoding='cp1252')

# %%
len(df)
# Out:
# 541909

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df.columns = [col.lower() for col in df.columns]

# %%
df.head()
# Out:
#   invoiceno stockcode                          description  quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       invoicedate  unitprice  customerid         country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.sample(10)
# Out:
#        invoiceno stockcode                        description  quantity  \
# 373991    569371     22910  PAPER CHAIN KIT VINTAGE CHRISTMAS         2
# 429242    573548     22694                       WICKER STAR          3
# 438501    574323    85170D    SET/6 PINK BIRD T-LIGHT CANDLES         2
# 395086    570983     21094      SET/6 RED SPOTTY PAPER PLATES         5
# 127721    547247     21314      SMALL GLASS HEART TRINKET POT         8
# 261992    559894     21162           TOXIC AREA  DOOR HANGER          2
# 58478     541244     85150      LADIES & GENTLEMEN METAL SIGN         1
# 283932    561820     21003          ROSE DU SUD CUSHION COVER         1
# 235050    557621    85231B         CINAMMON SET OF 9 T-LIGHTS        12
# 34966     539434     22107                 PIZZA PLATE IN BOX         3
#
#              invoicedate  unitprice  customerid         country
# 373991   10/3/2011 15:52       2.95     14651.0  United Kingdom
# ...

# %%
pd.to_datetime('5/26/2011 18:17',format='%m/%d/%Y %H:%M')
# Out:
# Timestamp('2011-05-26 18:17:00')

# %%
df['invoicedate'] = pd.to_datetime(df['invoicedate'],format='%m/%d/%Y %H:%M')

# %%
df.dtypes
# Out:
# invoiceno              object
# stockcode              object
# description            object
# quantity                int64
# invoicedate    datetime64[ns]
# unitprice             float64
# customerid            float64
# country                object
# dtype: object

# %%
df.head()
# Out:
#   invoiceno stockcode                          description  quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           invoicedate  unitprice  customerid         country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres@this_postgres')
name = 'sales'
df.to_sql(name, engine, if_exists='replace')

# %%
import psycopg2 as pg2

# %%
con = pg2.connect(host='this_postgres', user='postgres',database='postgres')

def select(sql):
    return pd.read_sql(sql,con)

sql = '''select count(*) from sales t'''

# %%
select(sql)
# Out:
#     count
# 0  541909

# %%
sql = '''select * from sales t limit 10'''

# %%
select(sql)
# Out:
#    index invoiceno stockcode                          description  quantity  \
# 0      0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      1    536365     71053                  WHITE METAL LANTERN         6
# 2      2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5      5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6      6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7      7    536366     22633               HAND WARMER UNION JACK         6
# 8      8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9      9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           invoicedate  unitprice  customerid         country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# ...
