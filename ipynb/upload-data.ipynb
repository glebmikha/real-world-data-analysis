# %%
import pandas as pd

# %%
df = pd.read_csv('../data/data.csv',encoding='cp1252')

# %%
len(df)
# Out:
# 541909

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df.columns = [col.lower() for col in df.columns]

# %%
df.head()
# Out:
#   invoiceno stockcode                          description  quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       invoicedate  unitprice  customerid         country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.sample(10)
# Out:
#        invoiceno stockcode                          description  quantity  \
# 412927    572302     22683        FRENCH BLUE METAL DOOR SIGN 8         1
# 149658    549296     23155  KNICKERBOCKERGLORY MAGNET ASSORTED         12
# 460387    575911     22576  SWALLOW WOODEN CHRISTMAS DECORATION        12
# 446680    574914     23148    MINIATURE ANTIQUE ROSE HOOK IVORY         2
# 221397    556245     23103         JINGLE BELL HEART DECORATION         2
# 205893    554842     23170             REGENCY TEA PLATE ROSES         12
# 121451    546764     22483              RED GINGHAM TEDDY BEAR          6
# 139389    548313     22398           MAGNETS PACK OF 4 SWALLOWS         4
# 221014    556237     23264   SET OF 3 WOODEN SLEIGH DECORATIONS         1
# 528852    580730     21065               BOOM BOX SPEAKER GIRLS         3
#
#              invoicedate  unitprice  customerid         country
# 412927  10/23/2011 14:47       1.25     15427.0  United Kingdom
# 149658     4/8/2011 7:37       0.83     14619.0  United Kingdom
# 460387  11/11/2011 16:13       0.85     17314.0  United Kingdom
# 446680   11/7/2011 16:16       0.83     17109.0  United Kingdom
# 221397    6/9/2011 16:10       1.65     17841.0  United Kingdom
# 205893   5/26/2011 18:17       1.65     14740.0  United Kingdom
# 121451   3/16/2011 14:31       2.95     15671.0  United Kingdom
# 139389   3/30/2011 12:15       1.25     15353.0  United Kingdom
# 221014    6/9/2011 15:34       2.50         NaN  United Kingdom
# 528852   12/5/2011 17:28       4.13         NaN  United Kingdom

# %%
pd.to_datetime('5/26/2011 18:17',format='%m/%d/%Y %H:%M')
# Out:
# Timestamp('2011-05-26 18:17:00')

# %%
df['invoicedate'] = pd.to_datetime(df['invoicedate'],format='%m/%d/%Y %H:%M')

# %%
df.dtypes
# Out:
# invoiceno              object
# stockcode              object
# description            object
# quantity                int64
# invoicedate    datetime64[ns]
# unitprice             float64
# customerid            float64
# country                object
# dtype: object

# %%
df.head()
# Out:
#   invoiceno stockcode                          description  quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           invoicedate  unitprice  customerid         country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres@this_postgres')
name = 'sales'
df.to_sql(name, engine, if_exists='replace')

# %%
import psycopg2 as pg2

# %%
con = pg2.connect(host='this_postgres', user='postgres',database='postgres')

def select(sql):
    return pd.read_sql(sql,con)

sql = '''select count(*) from sales t'''

# %%
select(sql)
# Out:
#     count
# 0  541909

# %%
sql = '''select * from sales t limit 10'''

# %%
select(sql)
# Out:
#    index invoiceno stockcode                          description  quantity  \
# 0      0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      1    536365     71053                  WHITE METAL LANTERN         6
# 2      2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5      5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6      6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7      7    536366     22633               HAND WARMER UNION JACK         6
# 8      8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9      9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           invoicedate  unitprice  customerid         country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 5 2010-12-01 08:26:00       7.65     17850.0  United Kingdom
# 6 2010-12-01 08:26:00       4.25     17850.0  United Kingdom
# 7 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 8 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 9 2010-12-01 08:34:00       1.69     13047.0  United Kingdom
